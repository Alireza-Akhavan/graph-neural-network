# %% [markdown]
# What is [karate club](https://class.vision/blog/%d9%85%d8%b9%d8%b1%d9%81%db%8c-%d8%af%db%8c%d8%aa%d8%a7%d8%b3%d8%aa-karate-club-%da%af%d8%b1%d8%a7%d9%81/) dataset?

# %%
import networkx as nx

G = nx.karate_club_graph() # load the Zachary's karate club graph
print('Number of nodes (club-members)', len(G.nodes))
nx.draw_networkx(G)
# Out:
# Number of nodes (club-members) 34

# %%
" plot the graph with labels"
labels = []
for i in G.nodes:
    club_names = G.nodes[i]['club']
    labels.append(1 if club_names == 'Officer' else 0) #Clubs: 'Officer' or 'Mr.Hi'
    
nx.draw_networkx(G,node_color = labels, cmap='coolwarm')
